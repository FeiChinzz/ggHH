# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten , Convolution2D, MaxPooling2D , Lambda, Conv2D, Activation,Concatenate, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Out:
# 2025-09-12 04:22:01.696317: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load image data #####

data_path = "/root/data/data_HLfeature.h5"
data_file = h5py.File(data_path, 'r')
data_file.keys()
# Out:
# <KeysViewHDF5 ['H_0', 'H_1', 'J1_tau21', 'J2_tau21', 'LB_1', 'SS_0', 'SS_1', 'X_HH', 'deta_JJ', 'iht', 'm_J1', 'm_J2', 'm_JJ', 'target2', 'target3']>

# %%
##### include data #####

sig_len = 470063
ttbarBG_len = 548709
jjBG_len = 270777

print("signal length:", sig_len)
print("ttbarBG length:", ttbarBG_len)
print("jjBG length:", jjBG_len)

features_tradition = ['X_HH', 'iht', 'm_JJ', 'm_J1', 'm_J2', 'deta_JJ', 'J1_tau21', 'J2_tau21']
features_TDA = ['X_HH', 'iht', 'm_JJ', 'm_J1', 'm_J2', 'deta_JJ', 'J1_tau21', 'J2_tau21', 'H_0', 'H_1', 'SS_0', 'SS_1', 'LB_1']
normalize_factor = [20, 1500, 2000, 300, 300, 4, 1, 1, 20, 1, 7, 5, 0.4]

data = []
for i, feature in enumerate(features_TDA):
    data.append(data_file[feature][:]/normalize_factor[i])
data = np.array(data).T

target = data_file["target2"][:]

train_data, val_data, train_target, val_target = train_test_split(data, target, test_size=0.2)

print("Shape of data:", np.shape(train_data))
print("Shape of target:", np.shape(train_target))
# Out:
# signal length: 470063
# ttbarBG length: 548709
# jjBG length: 270777
# Shape of data: (1031639, 13)
# Shape of target: (1031639,)

# %%
### build DNN model

DNN_TDA = Sequential()
DNN_TDA.add(keras.Input(shape=(13,)))
DNN_TDA.add(Dense(128, activation='relu'))
DNN_TDA.add(BatchNormalization())
DNN_TDA.add(Dense(64, activation='relu'))
DNN_TDA.add(BatchNormalization())
DNN_TDA.add(Dense(32, activation='relu'))
DNN_TDA.add(BatchNormalization())
DNN_TDA.add(Dense(16, activation='relu'))
DNN_TDA.add(BatchNormalization())
DNN_TDA.add(Dense(1, activation='sigmoid'))

### optimizer

opt = keras.optimizers.Adam(learning_rate=3e-4)

### compile

DNN_TDA.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

### model shape

print(DNN_TDA.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1792
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_3 (Dense)             (None, 16)                528
#
#  batch_normalization_3 (Bat  (None, 16)                64
#  chNormalization)
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 13633 (53.25 KB)
# Trainable params: 13153 (51.38 KB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________
# None
# 2025-09-12 04:22:04.841359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2025-09-12 04:22:04.842118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
### train and save the model

tr_DNN = DNN_TDA.fit(train_data, train_target, validation_data=(val_data, val_target), batch_size=512, epochs=100, verbose=1)
DNN_TDA.save("/root/data/DNN_model_TDA_normalized.h5")
# Out:
# Epoch 1/100
# 2025-09-12 04:22:07.701806: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-09-12 04:22:07.708079: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa2ec0182b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-12 04:22:07.708145: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-09-12 04:22:07.708157: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-09-12 04:22:07.717084: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-12 04:22:07.859001: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-09-12 04:22:07.986216: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 
100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4429 - accuracy: 0.7913 - mse: 0.1439 - val_loss: 0.4435 - val_accuracy: 0.7909 - val_mse: 0.1441
# Epoch 43/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4428 - accuracy: 0.7910 - mse: 0.1439 - val_loss: 0.4455 - val_accuracy: 0.7900 - val_mse: 0.1448
# Epoch 44/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4427 - accuracy: 0.7913 - mse: 0.1439 - val_loss: 0.4446 - val_accuracy: 0.7903 - val_mse: 0.1446
# Epoch 45/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4427 - accuracy: 0.7913 - mse: 0.1439 - val_loss: 0.4441 - val_accuracy: 0.7909 - val_mse: 0.1443
# Epoch 46/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4425 - accuracy: 0.7916 - mse: 0.1438 - val_loss: 0.4437 - val_accuracy: 0.7910 - val_mse: 0.1442
# Epoch 47/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4426 - accuracy: 0.7913 - mse: 0.1438 - val_loss: 0.4444 - val_accuracy: 0.7910 - val_mse: 0.1444
# Epoch 48/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4426 - accuracy: 0.7913 - mse: 0.1438 - val_loss: 0.4438 - val_accuracy: 0.7907 - val_mse: 0.1442
# Epoch 49/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4423 - accuracy: 0.7915 - mse: 0.1437 - val_loss: 0.4450 - val_accuracy: 0.7903 - val_mse: 0.1447
# Epoch 50/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4425 - accuracy: 0.7915 - mse: 0.1438 - val_loss: 0.4436 - val_accuracy: 0.7910 - val_mse: 0.1441
# Epoch 51/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4422 - accuracy: 0.7915 - mse: 0.1437 - val_loss: 0.4448 - val_accuracy: 0.7911 - val_mse: 0.1445
# Epoch 52/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4421 - accuracy: 0.7917 - mse: 0.1437 - val_loss: 0.4449 - val_accuracy: 0.7905 - val_mse: 0.1446
# Epoch 53/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4422 - accuracy: 0.7913 - mse: 0.1437 - val_loss: 0.4433 - val_accuracy: 0.7915 - val_mse: 0.1440
# Epoch 54/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4421 - accuracy: 0.7918 - mse: 0.1436 - val_loss: 0.4468 - val_accuracy: 0.7910 - val_mse: 0.1449
# Epoch 55/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4419 - accuracy: 0.7917 - mse: 0.1436 - val_loss: 0.4445 - val_accuracy: 0.7902 - val_mse: 0.1445
# Epoch 56/100
# 2015/2015 [==============================] - 15s 7ms/step - loss: 0.4419 - accuracy: 0.7918 - mse: 0.1436 - val_loss: 0.4481 - val_accuracy: 0.7889 - val_mse: 0.1458
# Epoch 57/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4418 - accuracy: 0.7918 - mse: 0.1435 - val_loss: 0.4442 - val_accuracy: 0.7911 - val_mse: 0.1443
# Epoch 58/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4418 - accuracy: 0.7917 - mse: 0.1435 - val_loss: 0.4455 - val_accuracy: 0.7901 - val_mse: 0.1448
# Epoch 59/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4418 - accuracy: 0.7918 - mse: 0.1435 - val_loss: 0.4441 - val_accuracy: 0.7910 - val_mse: 0.1442
# Epoch 60/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4415 - accuracy: 0.7918 - mse: 0.1434 - val_loss: 0.4447 - val_accuracy: 0.7907 - val_mse: 0.1445
# Epoch 61/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4416 - accuracy: 0.7919 - mse: 0.1435 - val_loss: 0.4453 - val_accuracy: 0.7909 - val_mse: 0.1447
# Epoch 62/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4415 - accuracy: 0.7921 - mse: 0.1435 - val_loss: 0.4460 - val_accuracy: 0.7896 - val_mse: 0.1451
# Epoch 63/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4415 - accuracy: 0.7918 - mse: 0.1434 - val_loss: 0.4450 - val_accuracy: 0.7902 - val_mse: 0.1446
# Epoch 64/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4413 - accuracy: 0.7922 - mse: 0.1434 - val_loss: 0.4449 - val_accuracy: 0.7907 - val_mse: 0.1445
# Epoch 65/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4414 - accuracy: 0.7920 - mse: 0.1434 - val_loss: 0.4454 - val_accuracy: 0.7902 - val_mse: 0.1448
# Epoch 66/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4413 - accuracy: 0.7921 - mse: 0.1434 - val_loss: 0.4490 - val_accuracy: 0.7879 - val_mse: 0.1460
# Epoch 67/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4412 - accuracy: 0.7921 - mse: 0.1433 - val_loss: 0.4437 - val_accuracy: 0.7914 - val_mse: 0.1441
# Epoch 68/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4412 - accuracy: 0.7922 - mse: 0.1433 - val_loss: 0.4447 - val_accuracy: 0.7908 - val_mse: 0.1445
# Epoch 69/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4412 - accuracy: 0.7924 - mse: 0.1433 - val_loss: 0.4459 - val_accuracy: 0.7895 - val_mse: 0.1451
# Epoch 70/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4412 - accuracy: 0.7922 - mse: 0.1434 - val_loss: 0.4467 - val_accuracy: 0.7895 - val_mse: 0.1452
# Epoch 71/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4411 - accuracy: 0.7922 - mse: 0.1433 - val_loss: 0.4449 - val_accuracy: 0.7906 - val_mse: 0.1444
# Epoch 72/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4411 - accuracy: 0.7920 - mse: 0.1433 - val_loss: 0.4447 - val_accuracy: 0.7904 - val_mse: 0.1446
# Epoch 73/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4411 - accuracy: 0.7921 - mse: 0.1433 - val_loss: 0.4440 - val_accuracy: 0.7910 - val_mse: 0.1443
# Epoch 74/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4409 - accuracy: 0.7923 - mse: 0.1432 - val_loss: 0.4435 - val_accuracy: 0.7914 - val_mse: 0.1441
# Epoch 75/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4408 - accuracy: 0.7925 - mse: 0.1432 - val_loss: 0.4454 - val_accuracy: 0.7910 - val_mse: 0.1445
# Epoch 76/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4408 - accuracy: 0.7921 - mse: 0.1432 - val_loss: 0.4441 - val_accuracy: 0.7913 - val_mse: 0.1443
# Epoch 77/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4408 - accuracy: 0.7925 - mse: 0.1432 - val_loss: 0.4437 - val_accuracy: 0.7913 - val_mse: 0.1442
# Epoch 78/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4408 - accuracy: 0.7926 - mse: 0.1432 - val_loss: 0.4515 - val_accuracy: 0.7880 - val_mse: 0.1468
# Epoch 79/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4408 - accuracy: 0.7922 - mse: 0.1432 - val_loss: 0.4443 - val_accuracy: 0.7905 - val_mse: 0.1444
# Epoch 80/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4408 - accuracy: 0.7926 - mse: 0.1432 - val_loss: 0.4446 - val_accuracy: 0.7910 - val_mse: 0.1445
# Epoch 81/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4406 - accuracy: 0.7926 - mse: 0.1431 - val_loss: 0.4488 - val_accuracy: 0.7889 - val_mse: 0.1459
# Epoch 82/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4406 - accuracy: 0.7922 - mse: 0.1431 - val_loss: 0.4440 - val_accuracy: 0.7907 - val_mse: 0.1443
# Epoch 83/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4405 - accuracy: 0.7926 - mse: 0.1431 - val_loss: 0.4449 - val_accuracy: 0.7911 - val_mse: 0.1446
# Epoch 84/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4405 - accuracy: 0.7923 - mse: 0.1431 - val_loss: 0.4450 - val_accuracy: 0.7910 - val_mse: 0.1446
# Epoch 85/100
# 2015/2015 [==============================] - 15s 8ms/step - loss: 0.4404 - accuracy: 0.7925 - mse: 0.1431 - val_loss: 0.4471 - val_accuracy: 0.7890 - val_mse: 0.1455
# Epoch 86/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4404 - accuracy: 0.7923 - mse: 0.1430 - val_loss: 0.4461 - val_accuracy: 0.7910 - val_mse: 0.1449
# Epoch 87/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4404 - accuracy: 0.7925 - mse: 0.1431 - val_loss: 0.4478 - val_accuracy: 0.7897 - val_mse: 0.1454
# Epoch 88/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4403 - accuracy: 0.7927 - mse: 0.1430 - val_loss: 0.4453 - val_accuracy: 0.7900 - val_mse: 0.1448
# Epoch 89/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4404 - accuracy: 0.7926 - mse: 0.1431 - val_loss: 0.4431 - val_accuracy: 0.7911 - val_mse: 0.1440
# Epoch 90/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4402 - accuracy: 0.7927 - mse: 0.1430 - val_loss: 0.4432 - val_accuracy: 0.7916 - val_mse: 0.1440
# Epoch 91/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4401 - accuracy: 0.7929 - mse: 0.1429 - val_loss: 0.4437 - val_accuracy: 0.7921 - val_mse: 0.1441
# Epoch 92/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4401 - accuracy: 0.7929 - mse: 0.1429 - val_loss: 0.4433 - val_accuracy: 0.7911 - val_mse: 0.1440
# Epoch 93/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4401 - accuracy: 0.7929 - mse: 0.1429 - val_loss: 0.4439 - val_accuracy: 0.7908 - val_mse: 0.1442
# Epoch 94/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4401 - accuracy: 0.7926 - mse: 0.1429 - val_loss: 0.4444 - val_accuracy: 0.7907 - val_mse: 0.1444
# Epoch 95/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4400 - accuracy: 0.7928 - mse: 0.1429 - val_loss: 0.4440 - val_accuracy: 0.7919 - val_mse: 0.1442
# Epoch 96/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4401 - accuracy: 0.7927 - mse: 0.1429 - val_loss: 0.4446 - val_accuracy: 0.7913 - val_mse: 0.1445
# Epoch 97/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4400 - accuracy: 0.7930 - mse: 0.1429 - val_loss: 0.4463 - val_accuracy: 0.7903 - val_mse: 0.1450
# Epoch 98/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4401 - accuracy: 0.7927 - mse: 0.1430 - val_loss: 0.4454 - val_accuracy: 0.7910 - val_mse: 0.1447
# Epoch 99/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4400 - accuracy: 0.7929 - mse: 0.1429 - val_loss: 0.4453 - val_accuracy: 0.7900 - val_mse: 0.1448
# Epoch 100/100
# 2015/2015 [==============================] - 16s 8ms/step - loss: 0.4399 - accuracy: 0.7927 - mse: 0.1429 - val_loss: 0.4482 - val_accuracy: 0.7900 - val_mse: 0.1455
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_DNN.history["loss"], label='training data',c='blue',linewidth = 3)
plt.plot(tr_DNN.history["val_loss"], label='validation data',c='red',linewidth = 3)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
### plot learning curve

fig, ax = plt.subplots(1,1, figsize=(8,8))
plt.plot(tr_DNN.history["accuracy"], label='training data',c='blue',linewidth = 3)
plt.plot(tr_DNN.history["val_accuracy"], label='validation data',c='red',linewidth = 3)
plt.title("DNN with TDA variable", fontsize=25)
ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
# plt.yscale("log")
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)
plt.show()

# %%
print("Time:", time.time()-t1)
# Out:
# Time: 1558.3607485294342
