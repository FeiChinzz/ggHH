# %%
import time
t1 = time.time()

import math
import os
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten , Convolution2D, MaxPooling2D , Lambda, Conv2D, Activation,Concatenate, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam , SGD , Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers , initializers
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Out:
# 2025-07-02 05:12:35.818648: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
##### load image data #####

image_path = "/root/data/data_image.h5"
image_file = h5py.File(image_path, 'r')
image_file.keys()
# Out:
# <KeysViewHDF5 ['jjBG', 'sig', 'ttbarBG']>

# %%
sig_len = 470063
jjBG_len = 270777
ttbarBG_len = 548709

print("signal length", sig_len)
print("jjBG length", jjBG_len)
print("ttbarBG length", ttbarBG_len)

total_image = np.concatenate((image_file['sig'][:], image_file['jjBG'][:], image_file['ttbarBG'][:]))
print("total image shape", np.shape(total_image))

print("Time:", time.time()-t1)
# Out:
# signal length 470063
# jjBG length 270777
# ttbarBG length 548709
# total image shape (1289549, 3, 50, 50)
# Time: 46.14120125770569

# %%
##### make target #####

target = np.zeros(sig_len + jjBG_len + ttbarBG_len)
target[0:sig_len] = 1    ### signal label as 1
print(target)
print("target shape", np.shape(target))
# Out:
# [1. 1. 1. ... 0. 0. 0.]
# target shape (1289549,)

# %%
##### split the data into training, validation and test data #####

train_image, val_image, train_target, val_target = train_test_split(total_image, target, test_size=0.2)

print("training data shape:", np.shape(train_image), np.shape(train_target))
print("validation data shape:", np.shape(val_image), np.shape(val_target))
# Out:
# training data shape: (1031639, 3, 50, 50) (1031639,)
# validation data shape: (257910, 3, 50, 50) (257910,)

# %%
##### build CNN model #####

CNN_model = Sequential()
CNN_model.add(Conv2D(16, kernel_size=(5,5), strides=(1,1), activation='relu',data_format='channels_first', kernel_initializer='he_normal', input_shape=(3,50,50)))
CNN_model.add(Conv2D(16, kernel_size=(5,5), strides=(1,1), activation='relu',data_format='channels_first', kernel_initializer='he_normal'))
CNN_model.add(MaxPooling2D(pool_size=(2,2), data_format='channels_first'))
CNN_model.add(Dropout(0.1))
CNN_model.add(BatchNormalization())

CNN_model.add(Conv2D(32, kernel_size=(5,5), strides=(1,1), activation='relu',data_format='channels_first', kernel_initializer='he_normal'))
CNN_model.add(Conv2D(32, kernel_size=(5,5), strides=(1,1), activation='relu',data_format='channels_first', kernel_initializer='he_normal'))
CNN_model.add(MaxPooling2D(pool_size=(2,2), data_format='channels_first'))
CNN_model.add(Dropout(0.1))
CNN_model.add(BatchNormalization())

CNN_model.add(Flatten())
CNN_model.add(Dense(64, activation='relu', kernel_initializer='he_normal'))
CNN_model.add(BatchNormalization())
CNN_model.add(Dropout(0.3))
CNN_model.add(Dense(1, activation='sigmoid'))

opt = keras.optimizers.Adam(learning_rate=1e-4)
CNN_model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","mse"])

CNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 46, 46)        1216
#
#  conv2d_1 (Conv2D)           (None, 16, 42, 42)        6416
#
#  max_pooling2d (MaxPooling2  (None, 16, 21, 21)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 21, 21)        0
#
#  batch_normalization (Batch  (None, 16, 21, 21)        84
#  Normalization)
#
#  conv2d_2 (Conv2D)           (None, 32, 17, 17)        12832
#
#  conv2d_3 (Conv2D)           (None, 32, 13, 13)        25632
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 6, 6)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 32, 6, 6)          0
#
#  batch_normalization_1 (Bat  (None, 32, 6, 6)          24
#  chNormalization)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 64)                73792
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 120317 (469.99 KB)
# Trainable params: 120135 (469.28 KB)
# Non-trainable params: 182 (728.00 Byte)
# _________________________________________________________________
# 2025-07-02 05:13:45.751260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2025-07-02 05:13:45.752038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
##### training model #####

batch_size = 1024
epochs = 100

tr_CNN_model = CNN_model.fit(train_image, train_target, validation_data=(val_image, val_target), batch_size=batch_size, epochs=epochs, verbose=1)
CNN_model.save("/root/data/model_CNN.h5")
# Out:
# 2025-07-02 05:14:45.083535: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 30949170000 exceeds 10% of free system memory.
# 2025-07-02 05:15:07.991477: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 30949170000 exceeds 10% of free system memory.
# Epoch 1/100
# 2025-07-02 05:15:22.729836: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ingradient_tape/sequential/dropout_1/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-02 05:15:25.654216: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-07-02 05:15:27.304011: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-07-02 05:15:27.309390: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563523a40dd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-02 05:15:27.309456: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-07-02 05:15:27.309469: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-07-02 05:15:27.318282: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-02 05:15:27.455307: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1008/1008 [==============================] - 54s 45ms/step - loss: 0.6406 - accuracy: 0.6556 - mse: 0.2182 - val_loss: 0.5489 - val_accuracy: 0.7245 - val_mse: 0.1848
# Epoch 2/100
# 1008/1008 [==============================] - 32s 32ms/step - loss: 0.5593 - accuracy: 0.7203 - mse: 0.1869 - val_loss: 0.5151 - val_accuracy: 0.7459 - val_mse: 0.1713
# Epoch 3/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.5247 - accuracy: 0.7423 - mse: 0.1742 - val_loss: 0.4956 - val_accuracy: 0.7583 - val_mse: 0.1638
# Epoch 4/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.5047 - accuracy: 0.7541 - mse: 0.1669 - val_loss: 0.4812 - val_accuracy: 0.7675 - val_mse: 0.1584
# Epoch 5/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4899 - accuracy: 0.7628 - mse: 0.1615 - val_loss: 0.4703 - val_accuracy: 0.7738 - val_mse: 0.1543
# Epoch 6/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4792 - accuracy: 0.7690 - mse: 0.1576 - val_loss: 0.4633 - val_accuracy: 0.7778 - val_mse: 0.1518
# Epoch 7/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4706 - accuracy: 0.7746 - mse: 0.1543 - val_loss: 0.4579 - val_accuracy: 0.7817 - val_mse: 0.1497
# Epoch 8/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4642 - accuracy: 0.7778 - mse: 0.1520 - val_loss: 0.4523 - val_accuracy: 0.7852 - val_mse: 0.1476
# Epoch 9/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4581 - accuracy: 0.7817 - mse: 0.1497 - val_loss: 0.4433 - val_accuracy: 0.7900 - val_mse: 0.1444
# Epoch 10/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4535 - accuracy: 0.7841 - mse: 0.1481 - val_loss: 0.4411 - val_accuracy: 0.7910 - val_mse: 0.1436
# Epoch 11/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4491 - accuracy: 0.7869 - mse: 0.1464 - val_loss: 0.4363 - val_accuracy: 0.7937 - val_mse: 0.1418
# Epoch 12/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4459 - accuracy: 0.7889 - mse: 0.1452 - val_loss: 0.4325 - val_accuracy: 0.7959 - val_mse: 0.1404
# Epoch 13/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4429 - accuracy: 0.7909 - mse: 0.1441 - val_loss: 0.4303 - val_accuracy: 0.7976 - val_mse: 0.1396
# Epoch 14/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4400 - accuracy: 0.7927 - mse: 0.1430 - val_loss: 0.4308 - val_accuracy: 0.7973 - val_mse: 0.1398
# Epoch 15/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4376 - accuracy: 0.7938 - mse: 0.1421 - val_loss: 0.4259 - val_accuracy: 0.8006 - val_mse: 0.1379
# Epoch 16/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4352 - accuracy: 0.7956 - mse: 0.1413 - val_loss: 0.4278 - val_accuracy: 0.7994 - val_mse: 0.1386
# Epoch 17/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4334 - accuracy: 0.7965 - mse: 0.1406 - val_loss: 0.4241 - val_accuracy: 0.8010 - val_mse: 0.1373
# Epoch 18/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4311 - accuracy: 0.7974 - mse: 0.1398 - val_loss: 0.4216 - val_accuracy: 0.8031 - val_mse: 0.1364
# Epoch 19/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4291 - accuracy: 0.7989 - mse: 0.1390 - val_loss: 0.4193 - val_accuracy: 0.8045 - val_mse: 0.1355
# Epoch 20/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4276 - accuracy: 0.7999 - mse: 0.1385 - val_loss: 0.4195 - val_accuracy: 0.8048 - val_mse: 0.1356
# Epoch 21/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4262 - accuracy: 0.8010 - mse: 0.1379 - val_loss: 0.4159 - val_accuracy: 0.8061 - val_mse: 0.1343
# Epoch 22/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4241 - accuracy: 0.8019 - mse: 0.1372 - val_loss: 0.4168 - val_accuracy: 0.8058 - val_mse: 0.1346
# Epoch 23/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4224 - accuracy: 0.8031 - mse: 0.1366 - val_loss: 0.4147 - val_accuracy: 0.8067 - val_mse: 0.1339
# Epoch 24/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4217 - accuracy: 0.8036 - mse: 0.1363 - val_loss: 0.4127 - val_accuracy: 0.8079 - val_mse: 0.1331
# Epoch 25/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4201 - accuracy: 0.8043 - mse: 0.1357 - val_loss: 0.4145 - val_accuracy: 0.8067 - val_mse: 0.1338
# Epoch 26/100
# 1008/1008 [==============================] - 32s 32ms/step - loss: 0.4190 - accuracy: 0.8050 - mse: 0.1353 - val_loss: 0.4101 - val_accuracy: 0.8099 - val_mse: 0.1321
# Epoch 27/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4175 - accuracy: 0.8057 - mse: 0.1348 - val_loss: 0.4124 - val_accuracy: 0.8082 - val_mse: 0.1330
# Epoch 28/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4164 - accuracy: 0.8067 - mse: 0.1343 - val_loss: 0.4092 - val_accuracy: 0.8097 - val_mse: 0.1318
# Epoch 29/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4152 - accuracy: 0.8072 - mse: 0.1339 - val_loss: 0.4083 - val_accuracy: 0.8104 - val_mse: 0.1315
# Epoch 30/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4140 - accuracy: 0.8075 - mse: 0.1336 - val_loss: 0.4069 - val_accuracy: 0.8117 - val_mse: 0.1310
# Epoch 31/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4128 - accuracy: 0.8086 - mse: 0.1331 - val_loss: 0.4072 - val_accuracy: 0.8110 - val_mse: 0.1311
# Epoch 32/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4119 - accuracy: 0.8090 - mse: 0.1328 - val_loss: 0.4053 - val_accuracy: 0.8126 - val_mse: 0.1304
# Epoch 33/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4108 - accuracy: 0.8098 - mse: 0.1324 - val_loss: 0.4040 - val_accuracy: 0.8137 - val_mse: 0.1299
# Epoch 34/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.4100 - accuracy: 0.8098 - mse: 0.1321 - val_loss: 0.4035 - val_accuracy: 0.8134 - val_mse: 0.1298
# Epoch 35/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4092 - accuracy: 0.8106 - mse: 0.1317 - val_loss: 0.4026 - val_accuracy: 0.8139 - val_mse: 0.1294
# Epoch 36/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4083 - accuracy: 0.8110 - mse: 0.1315 - val_loss: 0.4044 - val_accuracy: 0.8138 - val_mse: 0.1300
# Epoch 37/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4075 - accuracy: 0.8116 - mse: 0.1311 - val_loss: 0.4028 - val_accuracy: 0.8139 - val_mse: 0.1295
# Epoch 38/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4065 - accuracy: 0.8123 - mse: 0.1308 - val_loss: 0.4009 - val_accuracy: 0.8153 - val_mse: 0.1288
# Epoch 39/100
# 1008/1008 [==============================] - 30s 29ms/step - loss: 0.4055 - accuracy: 0.8128 - mse: 0.1305 - val_loss: 0.4010 - val_accuracy: 0.8148 - val_mse: 0.1289
# Epoch 40/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4047 - accuracy: 0.8131 - mse: 0.1301 - val_loss: 0.4005 - val_accuracy: 0.8158 - val_mse: 0.1286
# Epoch 41/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4042 - accuracy: 0.8136 - mse: 0.1299 - val_loss: 0.3993 - val_accuracy: 0.8159 - val_mse: 0.1282
# Epoch 42/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4031 - accuracy: 0.8143 - mse: 0.1296 - val_loss: 0.3991 - val_accuracy: 0.8164 - val_mse: 0.1281
# Epoch 43/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4025 - accuracy: 0.8146 - mse: 0.1294 - val_loss: 0.3975 - val_accuracy: 0.8172 - val_mse: 0.1276
# Epoch 44/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4018 - accuracy: 0.8149 - mse: 0.1291 - val_loss: 0.3966 - val_accuracy: 0.8176 - val_mse: 0.1272
# Epoch 45/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4013 - accuracy: 0.8153 - mse: 0.1289 - val_loss: 0.3964 - val_accuracy: 0.8177 - val_mse: 0.1272
# Epoch 46/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.4007 - accuracy: 0.8156 - mse: 0.1287 - val_loss: 0.3957 - val_accuracy: 0.8183 - val_mse: 0.1269
# Epoch 47/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.4001 - accuracy: 0.8159 - mse: 0.1285 - val_loss: 0.3967 - val_accuracy: 0.8177 - val_mse: 0.1272
# Epoch 48/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3996 - accuracy: 0.8161 - mse: 0.1283 - val_loss: 0.3954 - val_accuracy: 0.8180 - val_mse: 0.1268
# Epoch 49/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3988 - accuracy: 0.8164 - mse: 0.1280 - val_loss: 0.3945 - val_accuracy: 0.8193 - val_mse: 0.1264
# Epoch 50/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3980 - accuracy: 0.8173 - mse: 0.1277 - val_loss: 0.3953 - val_accuracy: 0.8189 - val_mse: 0.1268
# Epoch 51/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3975 - accuracy: 0.8174 - mse: 0.1276 - val_loss: 0.3950 - val_accuracy: 0.8184 - val_mse: 0.1267
# Epoch 52/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3970 - accuracy: 0.8177 - mse: 0.1273 - val_loss: 0.3946 - val_accuracy: 0.8186 - val_mse: 0.1265
# Epoch 53/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3966 - accuracy: 0.8180 - mse: 0.1272 - val_loss: 0.3940 - val_accuracy: 0.8187 - val_mse: 0.1264
# Epoch 54/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3959 - accuracy: 0.8187 - mse: 0.1269 - val_loss: 0.3944 - val_accuracy: 0.8190 - val_mse: 0.1264
# Epoch 55/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.3957 - accuracy: 0.8183 - mse: 0.1269 - val_loss: 0.3921 - val_accuracy: 0.8206 - val_mse: 0.1255
# Epoch 56/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3948 - accuracy: 0.8188 - mse: 0.1266 - val_loss: 0.3939 - val_accuracy: 0.8196 - val_mse: 0.1262
# Epoch 57/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3943 - accuracy: 0.8193 - mse: 0.1264 - val_loss: 0.3930 - val_accuracy: 0.8200 - val_mse: 0.1259
# Epoch 58/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3940 - accuracy: 0.8193 - mse: 0.1263 - val_loss: 0.3911 - val_accuracy: 0.8207 - val_mse: 0.1252
# Epoch 59/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3935 - accuracy: 0.8195 - mse: 0.1261 - val_loss: 0.3916 - val_accuracy: 0.8207 - val_mse: 0.1254
# Epoch 60/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.3927 - accuracy: 0.8200 - mse: 0.1258 - val_loss: 0.3903 - val_accuracy: 0.8217 - val_mse: 0.1249
# Epoch 61/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3924 - accuracy: 0.8199 - mse: 0.1257 - val_loss: 0.3905 - val_accuracy: 0.8218 - val_mse: 0.1249
# Epoch 62/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3919 - accuracy: 0.8205 - mse: 0.1255 - val_loss: 0.3901 - val_accuracy: 0.8219 - val_mse: 0.1248
# Epoch 63/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3912 - accuracy: 0.8213 - mse: 0.1253 - val_loss: 0.3901 - val_accuracy: 0.8216 - val_mse: 0.1248
# Epoch 64/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3909 - accuracy: 0.8212 - mse: 0.1251 - val_loss: 0.3906 - val_accuracy: 0.8212 - val_mse: 0.1249
# Epoch 65/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3907 - accuracy: 0.8215 - mse: 0.1251 - val_loss: 0.3892 - val_accuracy: 0.8222 - val_mse: 0.1245
# Epoch 66/100
# 1008/1008 [==============================] - 30s 29ms/step - loss: 0.3902 - accuracy: 0.8214 - mse: 0.1249 - val_loss: 0.3889 - val_accuracy: 0.8223 - val_mse: 0.1244
# Epoch 67/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3900 - accuracy: 0.8215 - mse: 0.1249 - val_loss: 0.3905 - val_accuracy: 0.8208 - val_mse: 0.1250
# Epoch 68/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3892 - accuracy: 0.8221 - mse: 0.1245 - val_loss: 0.3893 - val_accuracy: 0.8225 - val_mse: 0.1245
# Epoch 69/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3885 - accuracy: 0.8226 - mse: 0.1243 - val_loss: 0.3875 - val_accuracy: 0.8228 - val_mse: 0.1239
# Epoch 70/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3888 - accuracy: 0.8221 - mse: 0.1245 - val_loss: 0.3876 - val_accuracy: 0.8232 - val_mse: 0.1240
# Epoch 71/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3885 - accuracy: 0.8223 - mse: 0.1243 - val_loss: 0.3870 - val_accuracy: 0.8234 - val_mse: 0.1237
# Epoch 72/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3879 - accuracy: 0.8225 - mse: 0.1241 - val_loss: 0.3891 - val_accuracy: 0.8222 - val_mse: 0.1244
# Epoch 73/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3872 - accuracy: 0.8233 - mse: 0.1238 - val_loss: 0.3886 - val_accuracy: 0.8221 - val_mse: 0.1243
# Epoch 74/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3873 - accuracy: 0.8230 - mse: 0.1238 - val_loss: 0.3870 - val_accuracy: 0.8230 - val_mse: 0.1238
# Epoch 75/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3865 - accuracy: 0.8233 - mse: 0.1236 - val_loss: 0.3874 - val_accuracy: 0.8235 - val_mse: 0.1238
# Epoch 76/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3865 - accuracy: 0.8236 - mse: 0.1236 - val_loss: 0.3859 - val_accuracy: 0.8234 - val_mse: 0.1233
# Epoch 77/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3860 - accuracy: 0.8243 - mse: 0.1234 - val_loss: 0.3869 - val_accuracy: 0.8236 - val_mse: 0.1236
# Epoch 78/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3856 - accuracy: 0.8240 - mse: 0.1233 - val_loss: 0.3882 - val_accuracy: 0.8225 - val_mse: 0.1242
# Epoch 79/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3857 - accuracy: 0.8243 - mse: 0.1232 - val_loss: 0.3923 - val_accuracy: 0.8200 - val_mse: 0.1256
# Epoch 80/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3854 - accuracy: 0.8242 - mse: 0.1231 - val_loss: 0.3881 - val_accuracy: 0.8227 - val_mse: 0.1241
# Epoch 81/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3846 - accuracy: 0.8244 - mse: 0.1229 - val_loss: 0.3861 - val_accuracy: 0.8236 - val_mse: 0.1233
# Epoch 82/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3847 - accuracy: 0.8244 - mse: 0.1229 - val_loss: 0.3862 - val_accuracy: 0.8233 - val_mse: 0.1235
# Epoch 83/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3843 - accuracy: 0.8251 - mse: 0.1227 - val_loss: 0.3859 - val_accuracy: 0.8238 - val_mse: 0.1233
# Epoch 84/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3840 - accuracy: 0.8250 - mse: 0.1227 - val_loss: 0.3937 - val_accuracy: 0.8199 - val_mse: 0.1260
# Epoch 85/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3836 - accuracy: 0.8251 - mse: 0.1226 - val_loss: 0.3852 - val_accuracy: 0.8242 - val_mse: 0.1230
# Epoch 86/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3834 - accuracy: 0.8253 - mse: 0.1225 - val_loss: 0.3868 - val_accuracy: 0.8235 - val_mse: 0.1236
# Epoch 87/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3832 - accuracy: 0.8254 - mse: 0.1224 - val_loss: 0.3845 - val_accuracy: 0.8247 - val_mse: 0.1228
# Epoch 88/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3824 - accuracy: 0.8258 - mse: 0.1221 - val_loss: 0.3861 - val_accuracy: 0.8234 - val_mse: 0.1234
# Epoch 89/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.3825 - accuracy: 0.8258 - mse: 0.1222 - val_loss: 0.3842 - val_accuracy: 0.8244 - val_mse: 0.1227
# Epoch 90/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3825 - accuracy: 0.8260 - mse: 0.1221 - val_loss: 0.3842 - val_accuracy: 0.8245 - val_mse: 0.1227
# Epoch 91/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3822 - accuracy: 0.8255 - mse: 0.1221 - val_loss: 0.3840 - val_accuracy: 0.8248 - val_mse: 0.1226
# Epoch 92/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3818 - accuracy: 0.8264 - mse: 0.1219 - val_loss: 0.3842 - val_accuracy: 0.8249 - val_mse: 0.1226
# Epoch 93/100
# 1008/1008 [==============================] - 31s 31ms/step - loss: 0.3818 - accuracy: 0.8261 - mse: 0.1219 - val_loss: 0.3836 - val_accuracy: 0.8252 - val_mse: 0.1225
# Epoch 94/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3811 - accuracy: 0.8266 - mse: 0.1216 - val_loss: 0.3851 - val_accuracy: 0.8245 - val_mse: 0.1230
# Epoch 95/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3808 - accuracy: 0.8269 - mse: 0.1215 - val_loss: 0.3839 - val_accuracy: 0.8253 - val_mse: 0.1225
# Epoch 96/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3807 - accuracy: 0.8267 - mse: 0.1215 - val_loss: 0.3838 - val_accuracy: 0.8246 - val_mse: 0.1226
# Epoch 97/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3803 - accuracy: 0.8271 - mse: 0.1214 - val_loss: 0.3835 - val_accuracy: 0.8250 - val_mse: 0.1224
# Epoch 98/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3803 - accuracy: 0.8269 - mse: 0.1214 - val_loss: 0.3868 - val_accuracy: 0.8235 - val_mse: 0.1236
# Epoch 99/100
# 1008/1008 [==============================] - 30s 30ms/step - loss: 0.3798 - accuracy: 0.8272 - mse: 0.1212 - val_loss: 0.3831 - val_accuracy: 0.8255 - val_mse: 0.1223
# Epoch 100/100
# 1008/1008 [==============================] - 31s 30ms/step - loss: 0.3796 - accuracy: 0.8272 - mse: 0.1211 - val_loss: 0.3869 - val_accuracy: 0.8232 - val_mse: 0.1237
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
### plot learning curve
loss_fig, loss_ax = plt.subplots(1,1, figsize=(10,10))
plt.plot(tr_CNN_model.history["loss"], label='training data',c='blue',linewidth = 3)
plt.plot(tr_CNN_model.history["val_loss"], label='validation data',c='red',linewidth = 3)
plt.title("CNN", fontsize=25)
loss_ax.set_ylabel('loss', fontsize=25,horizontalalignment='right',y=1)
loss_ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)

acc_fig, acc_ax = plt.subplots(1,1, figsize=(10,10))
plt.plot(tr_CNN_model.history["accuracy"], label='training data',c='blue',linewidth = 3)
plt.plot(tr_CNN_model.history["val_accuracy"], label='validation data',c='red',linewidth = 3)
plt.title("CNN", fontsize=25)
acc_ax.set_ylabel('accuracy', fontsize=25,horizontalalignment='right',y=1)
acc_ax.set_xlabel('epoch', fontsize=25,horizontalalignment='right',x=1)
plt.legend(loc='best', prop={'size':20}, edgecolor = "w",fancybox=False, framealpha=0)

# %%
image_file.close()
t2 = time.time()
print("Total time (s): ", t2-t1)
# Out:
# Total time (s):  3238.8891565799713
