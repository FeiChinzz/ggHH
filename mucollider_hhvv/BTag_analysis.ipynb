# %%
########## import some useful package ##########

import time
t1 = time.time()

import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import ripser
import persim

# %%
########## read the data ##########

event_path = "/data/Chen-Wang/mucollider/hhvv/delphes_output.root"
data_file = uproot.open(event_path)

# %%
BTag = data_file["Delphes;1"]["VLCjetR10N2.BTag"].array()
leading_BTag = BTag[:,0]
subleading_BTag = BTag[:,1]

# %%
##### plot the histogram #####

fig = plt.figure(figsize=(16, 8))

fig.add_subplot(121)
plt.hist(leading_BTag)
plt.legend()

fig.add_subplot(122)
plt.hist(leading_BTag)
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
